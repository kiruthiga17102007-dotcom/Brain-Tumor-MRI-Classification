# %%
import zipfile

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('brain_tumor_dataset')

print("Extraction Completed!")
# Out:
# Extraction Completed!

# %%
import os

for folder in os.listdir('brain_tumor_dataset'):
    print(folder)
# Out:
# Training
# Testing

# %%
import os

train_path = 'brain_tumor_dataset/Training'
test_path = 'brain_tumor_dataset/Testing'

print(os.listdir(train_path))
# Out:
# ['notumor', 'meningioma', 'glioma', 'pituitary']

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'brain_tumor_dataset/Training',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 5600 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'brain_tumor_dataset/Testing',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1600 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 186624)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    23,888,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,907,908 (91.20 MB)
#  Trainable params: 23,907,908 (91.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model Compiled Successfully!")
# Out:
# Model Compiled Successfully!

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 544s 3s/step - accuracy: 0.8659 - loss: 0.3805 - val_accuracy: 0.7975 - val_loss: 0.7497
# Epoch 2/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 537s 3s/step - accuracy: 0.9209 - loss: 0.2203 - val_accuracy: 0.8606 - val_loss: 0.7231
# Epoch 3/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 539s 3s/step - accuracy: 0.9466 - loss: 0.1455 - val_accuracy: 0.8587 - val_loss: 0.8168
# Epoch 4/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 531s 3s/step - accuracy: 0.9659 - loss: 0.0965 - val_accuracy: 0.8800 - val_loss: 0.9514
# Epoch 5/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 538s 3s/step - accuracy: 0.9745 - loss: 0.0693 - val_accuracy: 0.8806 - val_loss: 0.9594
# Epoch 6/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 543s 3s/step - accuracy: 0.9821 - loss: 0.0502 - val_accuracy: 0.8687 - val_loss: 1.1005
# Epoch 7/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 542s 3s/step - accuracy: 0.9827 - loss: 0.0482 - val_accuracy: 0.8794 - val_loss: 1.2697
# Epoch 8/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 543s 3s/step - accuracy: 0.9896 - loss: 0.0354 - val_accuracy: 0.8819 - val_loss: 1.2566
# Epoch 9/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 576s 3s/step - accuracy: 0.9870 - loss: 0.0361 - val_accuracy: 0.8756 - val_loss: 1.4350
# Epoch 10/10
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 0.9875 - loss: 0.0361 - val_accuracy: 0.8756 - val_loss: 1.1636

# %%
import tensorflow as tf

test_data = tf.keras.utils.image_dataset_from_directory(
    "/content/brain_tumor_dataset/Testing",
    image_size=(224,224),
    batch_size=32
)
# Out:
# Found 1600 files belonging to 4 classes.

# %%
loss, accuracy = model.evaluate(test_generator)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 832ms/step - accuracy: 0.8756 - loss: 1.1636
# Test Loss: 1.163647174835205
# Test Accuracy: 0.8756250143051147

# %%
model.save("brain_tumor_mri_model.h5")
print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
